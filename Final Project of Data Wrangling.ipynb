# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 1. Import the dataset using Pandas from above mentioned url

# %%
import pandas as pd

# %%
Url = 'https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv'

# %%
users = pd.read_csv('https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv', sep = ',', index_col = 'iso_code')

# %%
users.head(10)
# Out:
#          continent     location      date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  31/12/19          NaN        0.0
# AFG           Asia  Afghanistan  01/01/20          NaN        0.0
# AFG           Asia  Afghanistan  02/01/20          NaN        0.0
# AFG           Asia  Afghanistan  03/01/20          NaN        0.0
# AFG           Asia  Afghanistan  04/01/20          NaN        0.0
# AFG           Asia  Afghanistan  05/01/20          NaN        0.0
# AFG           Asia  Afghanistan  06/01/20          NaN        0.0
# AFG           Asia  Afghanistan  07/01/20          NaN        0.0
# AFG           Asia  Afghanistan  08/01/20          NaN        0.0
# AFG           Asia  Afghanistan  09/01/20          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         0.0                  NaN
# ...

# %% [markdown]
# ### 2. High Level Data Understanding:
# ###    a. Find no. of rows & columns in the dataset
# ###    b. Data types of columns.
# ###    c. Info & describe of data in dataframe.

# %% [markdown]
# ### Number of columns

# %%
users.shape[1]
# Out:
# 48

# %% [markdown]
# ### Number of columns

# %%
len(users.index)
# Out:
# 57394

# %%
users.shape[0]
# Out:
# 57394

# %% [markdown]
# ### Data types of columns.

# %%
users.dtypes
# Out:
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# hosp_patients_per_million             float64
# ...

# %% [markdown]
# ### Info of data in dataframe.

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57394 entries, AFG to nan
# Data columns (total 48 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   continent                           56748 non-null  object
#  1   location                            57394 non-null  object
#  2   date                                57394 non-null  object
#  3   total_cases                         53758 non-null  float64
#  4   new_cases                           56465 non-null  float64
#  5   new_cases_smoothed                  55652 non-null  float64
#  6   total_deaths                        44368 non-null  float64
#  7   new_deaths                          56465 non-null  float64
#  8   new_deaths_smoothed                 55652 non-null  float64
#  9   total_cases_per_million             53471 non-null  float64
#  10  new_cases_per_million               56401 non-null  float64
# ...

# %% [markdown]
# ### Description of data in dataframe.

# %%
users.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# ### 3. Low Level Data Understanding :
# ### a. Find count of unique values in location column.
# ### b. Find which continent has maximum frequency using values counts.
# ### c. Find maximum & mean value in 'total_cases'.
# ### d. Find 25%,50% & 75% quartile value in 'total_deaths'.
# ### e. Find which continent has maximum 'human_development_index'.
# ### f. Find which continent has minimum 'gdp_per_capita'.

# %% [markdown]
# ### Count of unique values in location column.

# %%
users.location.nunique()
# Out:
# 216

# %% [markdown]
# ### Continent which has maximum frequency using values counts.

# %%
users.continent.value_counts().head(1).index[0]
# Out:
# 'Europe'

# %% [markdown]
# ### Maximum & Mean value in 'total_cases'.

# %%
users.total_cases.max()
# Out:
# 55154651.0

# %%
users.total_cases.mean()
# Out:
# 167797.3688753302

# %% [markdown]
# ### 25%,50% & 75% quartile value in 'total_deaths'.

# %%
users.total_deaths.describe()
# Out:
# count    4.436800e+04
# mean     6.858639e+03
# std      5.578081e+04
# min      1.000000e+00
# 25%      1.300000e+01
# 50%      8.400000e+01
# 75%      7.270000e+02
# max      1.328537e+06
# Name: total_deaths, dtype: float64

# %% [markdown]
# ### Continent which has maximum 'human_development_index'.

# %%
a = users.groupby(['continent'])['human_development_index'].max()
print (a)
print ('Europe',max(a))
# Out:
# continent
# Africa           0.797
# Asia             0.933
# Europe           0.953
# North America    0.926
# Oceania          0.939
# South America    0.843
# Name: human_development_index, dtype: float64
# Europe 0.953

# %% [markdown]
# ###  Continent which has minimum 'gdp_per_capita'.

# %%
b = users.groupby(['continent'])['gdp_per_capita'].min()
print (b)
print ('Africa',min(b))
# Out:
# continent
# Africa            661.240
# Asia             1479.147
# Europe           5189.972
# North America    1653.173
# Oceania          2205.923
# South America    6885.829
# Name: gdp_per_capita, dtype: float64
# Africa 661.24

# %% [markdown]
# ### 4. Filter the dataframe with only following columns ['continent','location','date','total_cases','total_deaths','gdp_per_capita','human_development_index'] and update the data frame

# %%
c = users[["continent","location","date","total_cases","total_deaths","gdp_per_capita","human_development_index"]]
print (c)
# Out:
#          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN           NaN
# AFG           Asia    Afghanistan  01/01/20          NaN           NaN
# AFG           Asia    Afghanistan  02/01/20          NaN           NaN
# AFG           Asia    Afghanistan  03/01/20          NaN           NaN
# AFG           Asia    Afghanistan  04/01/20          NaN           NaN
# ...            ...            ...       ...          ...           ...
# NaN            NaN  International  13/11/20        696.0           7.0
# NaN            NaN  International  14/11/20        696.0           7.0
# NaN            NaN  International  15/11/20        696.0           7.0
# NaN            NaN  International  16/11/20        696.0           7.0
# NaN            NaN  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# ### 5. Data Cleaning
#  ### a. Remove all duplicates observations
#  ### b. Find missing values in all columns
# ###  c. Remove all observations where continent column value is missing
#  ### Tip : using subset parameter in dropna
#  ### d. Fill all missing values with 0

# %% [markdown]
# ### Removing all duplicates observations

# %%
display(c.drop_duplicates())
# Out:
#          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          NaN           NaN
# AFG           Asia    Afghanistan  01/01/20          NaN           NaN
# AFG           Asia    Afghanistan  02/01/20          NaN           NaN
# AFG           Asia    Afghanistan  03/01/20          NaN           NaN
# AFG           Asia    Afghanistan  04/01/20          NaN           NaN
# ...            ...            ...       ...          ...           ...
# NaN            NaN  International  13/11/20        696.0           7.0
# NaN            NaN  International  14/11/20        696.0           7.0
# NaN            NaN  International  15/11/20        696.0           7.0
# NaN            NaN  International  16/11/20        696.0           7.0
# NaN            NaN  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# ###  Finding missing values in all columns

# %%
c.isnull()
# Out:
#           continent  location   date  total_cases  total_deaths  \
# iso_code
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# AFG           False     False  False         True          True
# ...             ...       ...    ...          ...           ...
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
# NaN            True     False  False        False         False
#
#           gdp_per_capita  human_development_index
# iso_code
# AFG                False                    False
# AFG                False                    False
# ...

# %% [markdown]
# ### Removing all observations where continent column value is missing

# %%
c.dropna(subset = 'continent')
# Out:
#          continent     location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia  Afghanistan  31/12/19          NaN           NaN
# AFG           Asia  Afghanistan  01/01/20          NaN           NaN
# AFG           Asia  Afghanistan  02/01/20          NaN           NaN
# AFG           Asia  Afghanistan  03/01/20          NaN           NaN
# AFG           Asia  Afghanistan  04/01/20          NaN           NaN
# ...            ...          ...       ...          ...           ...
# ZWE         Africa     Zimbabwe  13/11/20       8696.0         255.0
# ZWE         Africa     Zimbabwe  14/11/20       8765.0         257.0
# ZWE         Africa     Zimbabwe  15/11/20       8786.0         257.0
# ZWE         Africa     Zimbabwe  16/11/20       8786.0         257.0
# ZWE         Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#           gdp_per_capita  human_development_index
# iso_code
# AFG             1803.987                    0.498
# ...

# %% [markdown]
# ### Filling all missing values with 0

# %%
c.fillna(0)
# Out:
#          continent       location      date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan  31/12/19          0.0           0.0
# AFG           Asia    Afghanistan  01/01/20          0.0           0.0
# AFG           Asia    Afghanistan  02/01/20          0.0           0.0
# AFG           Asia    Afghanistan  03/01/20          0.0           0.0
# AFG           Asia    Afghanistan  04/01/20          0.0           0.0
# ...            ...            ...       ...          ...           ...
# NaN              0  International  13/11/20        696.0           7.0
# NaN              0  International  14/11/20        696.0           7.0
# NaN              0  International  15/11/20        696.0           7.0
# NaN              0  International  16/11/20        696.0           7.0
# NaN              0  International  17/11/20        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
# ### 6. Date time format :
#  ### a. Convert date column in datetime format using pandas.to_datetime
#  ### b. Create new column month after extracting month data from date column.

# %% [markdown]
#  ### Converting date column in datetime format using pandas.to_datetime

# %%
c['date'] = pd.to_datetime(c['date'])
print(c)
# Out:
#          continent       location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan 2019-12-31          NaN           NaN
# AFG           Asia    Afghanistan 2020-01-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-02-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-03-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-04-01          NaN           NaN
# ...            ...            ...        ...          ...           ...
# NaN            NaN  International 2020-11-13        696.0           7.0
# NaN            NaN  International 2020-11-14        696.0           7.0
# NaN            NaN  International 2020-11-15        696.0           7.0
# NaN            NaN  International 2020-11-16        696.0           7.0
# NaN            NaN  International 2020-11-17        696.0           7.0
#
#           gdp_per_capita  human_development_index
# iso_code
# ...

# %% [markdown]
#  ### Creating new column month after extracting month data from date column.

# %%
c['month'] = pd.DatetimeIndex(c['date']).month
print(c)
# Out:
#          continent       location       date  total_cases  total_deaths  \
# iso_code
# AFG           Asia    Afghanistan 2019-12-31          NaN           NaN
# AFG           Asia    Afghanistan 2020-01-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-02-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-03-01          NaN           NaN
# AFG           Asia    Afghanistan 2020-04-01          NaN           NaN
# ...            ...            ...        ...          ...           ...
# NaN            NaN  International 2020-11-13        696.0           7.0
# NaN            NaN  International 2020-11-14        696.0           7.0
# NaN            NaN  International 2020-11-15        696.0           7.0
# NaN            NaN  International 2020-11-16        696.0           7.0
# NaN            NaN  International 2020-11-17        696.0           7.0
#
#           gdp_per_capita  human_development_index  month
# iso_code
# ...

# %% [markdown]
# ### 7. Data Aggregation:
#  ### a. Find max value in all columns using groupby function on 'continent'column
#  ### Tip: use reset_index() after applying groupby
# ### b. Store the result in a new dataframe named 'df_groupby'.
#  ### (Use df_groupby dataframe for all further analysis)

# %% [markdown]
#  ### Maximum value in all columns using groupby function on 'continent' column and Storing the result in a new dataframe named 'df_groupby'.

# %%
c.groupby(['continent']).max()
# Out:
#                                    location       date  total_cases  \
# continent
# Africa                             Zimbabwe 2020-12-11     752269.0
# Asia                                  Yemen 2020-12-11    8874290.0
# Europe                              Vatican 2020-12-11    1991233.0
# North America  United States Virgin Islands 2020-12-11   11205486.0
# Oceania                   Wallis and Futuna 2020-12-11      27750.0
# South America                     Venezuela 2020-12-11    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index  month
# continent
# Africa              20314.0       26382.287                    0.797     12
# Asia               130519.0      116935.600                    0.933     12
# Europe              52147.0       94277.965                    0.953     12
# North America      247220.0       54225.446                    0.926     12
# Oceania               907.0       44648.710                    0.939     12
# ...

# %%
df_groupby = c.reset_index()
print (df_groupby)
# Out:
#       iso_code continent       location       date  total_cases  total_deaths  \
# 0          AFG      Asia    Afghanistan 2019-12-31          NaN           NaN
# 1          AFG      Asia    Afghanistan 2020-01-01          NaN           NaN
# 2          AFG      Asia    Afghanistan 2020-02-01          NaN           NaN
# 3          AFG      Asia    Afghanistan 2020-03-01          NaN           NaN
# 4          AFG      Asia    Afghanistan 2020-04-01          NaN           NaN
# ...        ...       ...            ...        ...          ...           ...
# 57389      NaN       NaN  International 2020-11-13        696.0           7.0
# 57390      NaN       NaN  International 2020-11-14        696.0           7.0
# 57391      NaN       NaN  International 2020-11-15        696.0           7.0
# 57392      NaN       NaN  International 2020-11-16        696.0           7.0
# 57393      NaN       NaN  International 2020-11-17        696.0           7.0
#
# ...

# %% [markdown]
# ### 8. Feature Engineering :
#  ### a. Create a new feature 'total_deaths_to_total_cases' by ratio of 'total_deaths' column to 'total_cases'

# %%
df_groupby['total_deaths_to_total_cases'] = df_groupby['total_cases'] / df_groupby['total_deaths']

# %%
df_groupby
# Out:
#       iso_code continent       location       date  total_cases  total_deaths  \
# 0          AFG      Asia    Afghanistan 2019-12-31          NaN           NaN
# 1          AFG      Asia    Afghanistan 2020-01-01          NaN           NaN
# 2          AFG      Asia    Afghanistan 2020-02-01          NaN           NaN
# 3          AFG      Asia    Afghanistan 2020-03-01          NaN           NaN
# 4          AFG      Asia    Afghanistan 2020-04-01          NaN           NaN
# ...        ...       ...            ...        ...          ...           ...
# 57389      NaN       NaN  International 2020-11-13        696.0           7.0
# 57390      NaN       NaN  International 2020-11-14        696.0           7.0
# 57391      NaN       NaN  International 2020-11-15        696.0           7.0
# 57392      NaN       NaN  International 2020-11-16        696.0           7.0
# 57393      NaN       NaN  International 2020-11-17        696.0           7.0
#
# ...

# %% [markdown]
# ### 9. Data Visualization :
# ### a. Perform Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.
# ### b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'
# ### c. Plot Pairplot on df_groupby dataset.
# ### d. Plot a bar plot of 'continent' column with 'total_cases' .
# ### Tip : using kind='bar' in seaborn catplot

# %% [markdown]
# ### Performing Univariate analysis on 'gdp_per_capita' column by plotting histogram using seaborn dist plot.

# %%
pip install seaborn
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      -------------------------------------- 293.3/293.3 kB 3.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.5/7.5 MB 1.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.9/1.9 MB 6.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 470.4/470.4 kB 7.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 55.3/55.3 kB 2.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 6.4 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data=df_groupby, x=df_groupby["gdp_per_capita"])
plt.title("GDP per capita")
plt.show()

# %% [markdown]
# ### Plotting a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
sns.scatterplot(x="total_cases", y="gdp_per_capita", data=df_groupby)
# Out:
# <Axes: xlabel='total_cases', ylabel='gdp_per_capita'>

# %%
sns.scatterplot(x="gdp_per_capita", y="total_cases", data=df_groupby)
# Out:
# <Axes: xlabel='gdp_per_capita', ylabel='total_cases'>

# %% [markdown]
# ### Plotting Pairplot on df_groupby dataset.

# %%
sns.pairplot(df_groupby)
#plt.show()
# Out:
# c:\Users\parul\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Plotting a bar plot of 'continent' column with 'total_cases' .
#  ### Tip : using kind='bar' in seaborn catplot

# %%
sns.barplot ( data=df_groupby, x="continent", y="total_cases")
plt.title("Bar plot of continent with total cases")
plt.show()

# %% [markdown]
# ### 10.Save the df_groupby dataframe in your local drive using pandas.to_csv function .

# %%
df_groupby.to_csv('file1.csv')
